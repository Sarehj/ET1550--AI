# %%
# Classification Neural Networks
# Introduction to Machine Learning and Artificial Intelligence (ET1550)
# Saleh Javadi
# BTH 2023

# %%
# Import libraries
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset = pd.read_csv('ionosphere.csv', header=None)

# %%
# Check the description of the dataset
dataset.describe()
# Out:
#                0      1           2           3           4           5   \
# count  351.000000  351.0  351.000000  351.000000  351.000000  351.000000
# mean     0.891738    0.0    0.641342    0.044372    0.601068    0.115889
# std      0.311155    0.0    0.497708    0.441435    0.519862    0.460810
# min      0.000000    0.0   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.0    0.472135   -0.064735    0.412660   -0.024795
# 50%      1.000000    0.0    0.871110    0.016310    0.809200    0.022800
# 75%      1.000000    0.0    1.000000    0.194185    1.000000    0.334655
# max      1.000000    0.0    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9   ...          25  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.550095    0.119360    0.511848    0.181345  ...   -0.071187
# std      0.492654    0.520750    0.507066    0.483851  ...    0.508495
# ...

# %%
# Check the shape of the dataset
dataset.head()
# Out:
#    0   1        2        3        4        5        6        7        8   \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#         9   ...       25       26       27       28       29       30  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#         31       32       33  34
# 0 -0.54487  0.18641 -0.45300   1
# 1 -0.06288 -0.13738 -0.02447   0
# ...

# %%
# Separate input from output
y = dataset.values[:, 34]
X = dataset.values[:, 0:34]

# %%
# Split datasets into train and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=100)

# %%
n_features = X_train.shape[1]

# %%
import tensorflow as tf
from tensorflow.keras import layers
# from tensorflow.keras import regularizers

model_NN = tf.keras.Sequential([
    layers.Dense(12, activation='relu', input_shape=(n_features,)),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# %%
# compile the model
model_NN.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# fit the model
model_NN.fit(X_train, y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 3ms/step - loss: 0.8781 - accuracy: 0.3429
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7878 - accuracy: 0.3306
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7245 - accuracy: 0.3388
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.3469
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6690 - accuracy: 0.4082
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6531 - accuracy: 0.5837
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6438 - accuracy: 0.7020
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6379 - accuracy: 0.7755
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6327 - accuracy: 0.8204
# Epoch 10/200
# ...

# %%
results = model_NN.evaluate(X_test, y_test)
print("test loss, test acc:", results)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2801 - accuracy: 0.9151
# test loss, test acc: [0.280110239982605, 0.9150943160057068]
